# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# %%
t, x1, y1, x2, y2, T, V = np.loadtxt("RungeKutta2_C/FoSM2_3b.dat", unpack=True)
#t2, y2 = np.loadtxt("FoSM2_2c.dat", unpack=True)

print(len(x1))
plt.plot(x1, y1)
plt.plot(x2, y2)
plt.show()

E = T + V # energy E(t)
E0 = E[0]

plt.plot(t, ((E-E0)/E0))
plt.title("Relative Energy Error")
plt.ylabel("(E(t) - E0) / E0")
plt.xlabel("t")
plt.savefig("energy_error_RK2")
plt.show()
# Out:
# 2001

# %%
t4, x14, y14, x24, y24, T4, V4, phi14, phi24 = np.loadtxt("RungeKutta4_C/FoSM2_3d.dat", unpack=True)
#t2, y2 = np.loadtxt("FoSM2_2c.dat", unpack=True)

print(len(x14))
plt.plot(x14, y14)
plt.plot(x24, y24)
plt.xlim(-2.5,2.5)
plt.title("Trajectory of the double pendulum")
plt.savefig("trajectory")
plt.show()

E4 = T4 + V4 # energy E(t)
E04 = E4[0]

plt.plot(t4, ((E4-E04)/E04))
plt.title("Relative Energy Error")
plt.ylabel("(E(t) - E0) / E0")
plt.xlabel("t")
plt.savefig("energy_error_RK4")
plt.show()

plt.plot(t4, ((E4-E04)/E04))
plt.plot(t, ((E-E0)/E0))
plt.title("Compare Relative Energy Error of RK2 & RK4")
plt.ylabel("(E(t) - E0) / E0")
plt.xlabel("t")
plt.ylim(-0.005)
plt.savefig("error_comparison")
plt.show()
# Out:
# 2001
